# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_columns = None

# %%
alumno_df = pd.read_csv('/content/drive/MyDrive/Hackaton/clean-data/Alumno.csv', index_col=0)
tabla_df = pd.read_csv('/content/drive/MyDrive/Hackaton/clean-data/Tabla.csv', index_col=0)
depto_df = pd.read_csv('/content/drive/MyDrive/Hackaton/clean-data/Depto.csv', index_col=0)
escuela_df = pd.read_csv('/content/drive/MyDrive/Hackaton/clean-data/Escuela.csv', index_col=0)
provincia_df = pd.read_csv('/content/drive/MyDrive/Hackaton/clean-data/Provincia.csv', index_col=0)
aprender_2018_df = pd.read_csv('/content/drive/MyDrive/Hackaton/clean-data/aprender_2018_primario.csv', sep = ';')



df = tabla_df.copy()
df = df.replace('nc', np.nan) 


tec_df = df.loc[:, ['tiene_notebook', 'tiene_celular', 'tiene_pc','tiene_tablet', 'tiene_smartphone', 'tiene_consola', 'tiene_cable', 'tiene_smarttv']]
#filtrada = samples_df.dropna() #Filtro todos los Nan
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (113) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#aprender_2018_df.columns
#df.year_id.value_counts()
#aprender_2018_df.shape

# %%
df.isnull().sum()
# Out:
# escuela_id                               0
# id                                       0
# sexo                                820594
# indice_socioeconomico               597777
# nivel_desemp_matematica             723968
# nivel_desemp_lengua                 739481
# nivel_desemp_ciencias_sociales      742111
# nivel_desemp_ciencias_naturales     783195
# ponderador_lengua                   139264
# ponderador_matematica               108978
# ponderador_ciencias_naturales       103320
# ponderador_ciencias_sociales         79286
# tiene_notebook                     1079425
# tiene_pc                           1079425
# tiene_tablet                       1079425
# tiene_celular                      1079425
# tiene_smartphone                   1079425
# tiene_consola                      1079425
# tiene_smarttv                      1079425
# tiene_cable                        1079425
# repeticion_primaria                 750457
# repeticion_secundaria              1773580
# ...

# %% [markdown]
# Cambio las variables categoricas en variables numericas

# %%
#tec_df.isnull().sum()
tec_df[tec_df.isnull()] = -1 
tec_df[tec_df == 'no'] = 0 
tec_df[tec_df == 'si'] = 1

# %% [markdown]
# Ingreso tabla de características y la arreglo.

# %%
car_2011_df= pd.read_csv('/content/drive/MyDrive/Hackaton/clean-data/2011/2011_caracteristicas.csv', sep = ';', encoding='latin1')
car_2011_df.columns = car_2011_df.columns.str.replace(' ', '_')
car_2011_df.columns = car_2011_df.columns.str.replace('_-_', '_')
car_2011_df
# Out:
#                    ID1     provincia   sector  ambito Electricidad_Si  \
# 0       20004002000400       Mendoza  Estatal  Urbano               X
# 1       20008002000800       Mendoza  Estatal  Urbano               X
# 2       21604002160400      Misiones  Estatal  Urbano               X
# 3       26404002640400         Salta  Estatal   Rural               X
# 4       32804003280400      Santa Fe  Estatal   Rural               X
# ...                ...           ...      ...     ...             ...
# 47003  999702224502099         Chaco  Estatal  Urbano               X
# 47004  999702621180999  Buenos Aires  Estatal  Urbano             NaN
# 47005  999702632400999  Buenos Aires  Estatal   Rural             NaN
# 47006  999726344450499      Santa Fe  Estatal   Rural               X
# 47007  999804265200099        Chubut  Estatal  Urbano               X
#
#       Electricidad_Red_pública Electricidad_Grupo_electrógeno  \
# 0                            X                            NaN
# ...

# %%
car_2019_df= pd.read_csv('/content/drive/MyDrive/Hackaton/clean-data/2019/2019_caracteristicas.csv', sep = ';', encoding='latin1')
car_2019_df.columns = car_2019_df.columns.str.replace(' ', '_')
car_2019_df.columns = car_2019_df.columns.str.replace('_-_', '_') 

car_2019_df
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                    ID1            provincia   sector  ambito Electricidad_Si  \
# 0       20004002000400              Mendoza  Estatal  Urbano               X
# 1       20008002000800              Mendoza  Privado  Urbano               X
# 2       21604002160400             Misiones  Estatal  Urbano               X
# 3       26404002640400                Salta  Estatal   Rural               X
# 4       28004002800400             San Juan  Estatal  Urbano               X
# ...                ...                  ...      ...     ...             ...
# 49724  999702224502099                Chaco  Estatal  Urbano               X
# 49725  999702632400999         Buenos Aires  Estatal   Rural               X
# ...
