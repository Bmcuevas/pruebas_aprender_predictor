# %% [markdown]
# **ESTE ARCHIVO ES PARA EXPANDIR LA INFORMACION QUE PODEMOS OBTENER SOBRE EL DF HACIENDO MAS GRAFICOS QUE QUIZAS ESTEN PIOLAS. AGREGUEN IDEAS CON # PARA CREAR SECCION**

# %% [markdown]
# # Cosas necesarias del principio

# %% [markdown]
# Importo librerias y tabla ya limpia, haciendo la copia

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import seaborn as sn
import missingno as msno
import scipy.stats as stats
from scipy.stats import norm
import matplotlib.mlab as mlab
import pylab 


clean_tabla_df = pd.read_csv('/content/drive/MyDrive/Hackaton/clean-data/clean_tabla.csv', index_col=0)
df = clean_tabla_df.copy()
df = df[df['nivel_id'] == 3]
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#            escuela_id  sexo  ...  departamento_id provincia_id
# id                           ...
# 1037297.0  1037567817   NaN  ...              0.0          0.0
# 1014085.0  1037567817   NaN  ...              0.0          0.0
# 67702.0    2004740133   NaN  ...              0.0          0.0
# 1130145.0  1037567817   NaN  ...              0.0          0.0
# 218677.0   1548760025   NaN  ...              0.0          0.0
#
# [5 rows x 52 columns]

# %%
df = df[df['indice_socioeconomico_medio'] != -1]
df.indice_socioeconomico_medio.describe()
# Out:
# count    670473.000000
# mean          2.026306
# std           0.341641
# min           1.000000
# 25%           1.800000
# 50%           2.000000
# 75%           2.243243
# max           3.000000
# Name: indice_socioeconomico_medio, dtype: float64

# %%
sn.distplot(df.indice_socioeconomico_medio,bins=15,color='#c7c7c7',fit=norm)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
mean=2.026306
std=0.341641

stats.shapiro(df.indice_socioeconomico_medio)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# (0.9964035749435425, 0.0)
